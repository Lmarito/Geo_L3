# %% [markdown]
# # Cours "Géomatique" - Folium
# ### Louis Maritaud
# ### louis.maritaud@unilim.fr

# %% [markdown]
# ## Objectifs pédagogiques
# - Comprendre les différences entre cartes statiques et cartes interactives
# - Créer des cartes web avec Folium
# - Ajouter des marqueurs et des popups personnalisés
# - Visualiser des données géographiques de manière interactive
# - Exporter des cartes HTML

# %% [markdown]
# # Résumé de ce qu'on a vu
#
# ## GeoPandas et les GeoDataFrame
# GeoPandas est une extension de Pandas qui permet de manipuler des données géographiques. Un **GeoDataFrame** est un DataFrame avec une colonne spéciale appelée `geometry` qui contient les informations géométriques (points, lignes, polygones).
#
# **Syntaxe de base :**
# ```python
# import geopandas as gpd
#
# # Lire un fichier géographique
# gdf = gpd.read_file("fichier.shp") # On peut lire des shapefiles ou des geojson, je préfère juste les geojson
#
# # Voir les premières lignes
# gdf.head()
#
# # Afficher sur une carte simple
# gdf.plot()
# ```
#
# ## Les systèmes de coordonnées (CRS)
# Le **CRS** (Coordinate Reference System) définit comment les coordonnées sont interprétées :
# - **EPSG:4326** (WGS84) : système latitude/longitude utilisé par le GPS
# - **EPSG:2154** (Lambert-93) : système de projection pour la France métropolitaine
#
# **Syntaxe :**
# ```python
# # Vérifier le CRS
# gdf.crs
#
# # Reprojeter en WGS84 (nécessaire pour Folium)
# gdf = gdf.to_crs(epsg=4326)
# ```
#
# ## Création de cartes statiques avec matplotlib
# ```python
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots(figsize=(10, 10))
# gdf.plot(ax=ax, color='blue', edgecolor='black')
# plt.title("Ma carte")
# plt.show()
# ```

# %% [markdown]
# # Folium, c'est quoi ?
#
# **Folium** est une bibliothèque Python qui permet de créer des **cartes interactives** pour le web. Ces cartes peuvent être :
# - Zoomées et déplacées par l'utilisateur
# - Enrichies avec des popups cliquables
# - Exportées en HTML pour être partagées
# - Intégrées dans des sites web ou des notebooks Jupyter
#
# **Différences avec matplotlib :**
# - matplotlib → cartes **statiques** (images fixes)
# - Folium → cartes **interactives** (navigation, zoom, clics)
#
# **Folium utilise la bibliothèque JavaScript Leaflet**, ce qui permet d'avoir des cartes web professionnelles sans connaître JavaScript. En gros on écrit tout en Python, qui recompile en JS.
#
# ## Structure d'une carte Folium
#
# Une carte Folium se construit en plusieurs étapes :
# 1. **Créer la carte de base** avec `folium.Map()`
# 2. **Ajouter des éléments** (marqueurs, polygones, etc.)
# 3. **Afficher ou sauvegarder** la carte

# %% [markdown]
# ### Installation
#
# ```python
# # À exécuter une seule fois dans votre terminal ou notebook
# pip install folium
# ```

# %% [markdown]
# # Manipulation

# %%
# Import de Folium
import folium

# Créer une carte centrée sur Limoges
# Les coordonnées sont au format [latitude, longitude]
carte = folium.Map(
    location=[45.85, 1.25],  # Centre de la carte (Limoges)
    zoom_start=13,            # Niveau de zoom initial (1=monde, 20=rue)
    tiles='OpenStreetMap'     # Fond de carte
)

# Afficher la carte dans le notebook
carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd4280af7247c7216c77ee718cfdae91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd4280af7247c7216c77ee718cfdae91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd4280af7247c7216c77ee718cfdae91 = L.map(
#                 &quot;map_cd4280af7247c7216c77ee718cfdae91&quot;,
#                 {
#                     center: [45.85, 1.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d378f032bb0720675245e76b4d31d13a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d378f032bb0720675245e76b4d31d13a.addTo(map_cd4280af7247c7216c77ee718cfdae91);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # EXERCICE 1
# Créez une carte centrée sur une ville de votre choix, et ajustez le niveau de zoom

# %%
# Votre code ici

# %% [markdown]
# ## Les différents fonds de carte (tiles)
#
# Folium propose plusieurs fonds de carte :
# - `'OpenStreetMap'` : fond par défaut, très détaillé
# - `'CartoDB positron'` : fond clair et épuré
# - `'CartoDB dark_matter'` : fond sombre

# %%
# Carte avec un fond clair
carte_claire = folium.Map(
    location=[45.85, 1.25],
    zoom_start=12,
    tiles='CartoDB Positron'
)

carte_claire
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_486838def81bc13b021d28a006e314a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_486838def81bc13b021d28a006e314a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_486838def81bc13b021d28a006e314a6 = L.map(
#                 &quot;map_486838def81bc13b021d28a006e314a6&quot;,
#                 {
#                     center: [45.85, 1.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9b157b8417f27e5eef70ee5a2d898d6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9b157b8417f27e5eef70ee5a2d898d6.addTo(map_486838def81bc13b021d28a006e314a6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Ajouter des marqueurs
#
# Les marqueurs permettent de localiser des points précis sur la carte.

# %%
# Créer une carte
carte = folium.Map(
    location=[45.85, 1.25],
    zoom_start=13
)

# Ajouter un marqueur simple
folium.Marker(
    location=[45.836286250961614, 1.2674356978313563],  # Coordonnées de la gare de Limoges
    popup='Gare de Limoges-Bénédictins',  # Texte qui apparaît au clic
    tooltip='Cliquez pour plus d\'infos',  # Texte au survol
    icon=folium.Icon(color='red', icon='info-sign')  # Icône personnalisée
).add_to(carte)

# Ajouter un deuxième marqueur
folium.Marker(
    location=[45.829007591942876, 1.2659717635642285],  # Cathédrale
    popup='Cathédrale Saint-Étienne',
    icon=folium.Icon(color='blue', icon='church', prefix='fa')
).add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a31adf4ddb53ff2b457e327182fc008 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a31adf4ddb53ff2b457e327182fc008&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a31adf4ddb53ff2b457e327182fc008 = L.map(
#                 &quot;map_5a31adf4ddb53ff2b457e327182fc008&quot;,
#                 {
#                     center: [45.85, 1.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8647232f5f66c6b803ea07b5d93e5d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8647232f5f66c6b803ea07b5d93e5d7.addTo(map_5a31adf4ddb53ff2b457e327182fc008);
#
#
#             var marker_eb718ccb518aeff762534c9042bf03d4 = L.marker(
#                 [45.836286250961614, 1.2674356978313563],
#                 {
# }
#             ).addTo(map_5a31adf4ddb53ff2b457e327182fc008);
#
#
#             var icon_4cca88b36f7c04c46a7d6adc237aebee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fad0a7fff7901a53e23325a72f63a716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28118547e63e462cba643f5b7ddee121 = $(`&lt;div id=&quot;html_28118547e63e462cba643f5b7ddee121&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gare de Limoges-Bénédictins&lt;/div&gt;`)[0];
#                 popup_fad0a7fff7901a53e23325a72f63a716.setContent(html_28118547e63e462cba643f5b7ddee121);
#
#
#
#         marker_eb718ccb518aeff762534c9042bf03d4.bindPopup(popup_fad0a7fff7901a53e23325a72f63a716)
#         ;
#
#
#
#
#             marker_eb718ccb518aeff762534c9042bf03d4.bindTooltip(
#                 `&lt;div&gt;
#                      Cliquez pour plus d&#x27;infos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_eb718ccb518aeff762534c9042bf03d4.setIcon(icon_4cca88b36f7c04c46a7d6adc237aebee);
#
#
#             var marker_0b7443c94e4e1adb4781eb1255b90d64 = L.marker(
#                 [45.829007591942876, 1.2659717635642285],
#                 {
# }
#             ).addTo(map_5a31adf4ddb53ff2b457e327182fc008);
#
#
#             var icon_998d35b3ad2d4963c2f99781317accef = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;church&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_54eef6cf87d6ac57cf288c23b9064ad9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc28318e3e03368ff9b9f9ed099de31f = $(`&lt;div id=&quot;html_dc28318e3e03368ff9b9f9ed099de31f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cathédrale Saint-Étienne&lt;/div&gt;`)[0];
#                 popup_54eef6cf87d6ac57cf288c23b9064ad9.setContent(html_dc28318e3e03368ff9b9f9ed099de31f);
#
#
#
#         marker_0b7443c94e4e1adb4781eb1255b90d64.bindPopup(popup_54eef6cf87d6ac57cf288c23b9064ad9)
#         ;
#
#
#
#
#                 marker_0b7443c94e4e1adb4781eb1255b90d64.setIcon(icon_998d35b3ad2d4963c2f99781317accef);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # EXERCICE 2
# Créez une carte avec au moins 3 marqueurs représentant des lieux importants de votre ville (université, monuments, restaurants, etc.). Utilisez des couleurs différentes pour chaque type de lieu.

# %%
# Votre code ici

# %% [markdown]
# ## Marqueurs circulaires et personnalisation
#
# Les `CircleMarker` sont utiles pour représenter des données avec des tailles proportionnelles.

# %%
import pandas as pd

# Données des principales villes du Limousin
villes = pd.DataFrame({
    'ville': ['Limoges', 'Brive-la-Gaillarde', 'Tulle', 'Guéret'],
    'latitude': [45.85, 45.1586, 45.2655, 46.1702],
    'longitude': [1.25, 1.5339, 1.7711, 1.8716],
    'population': [129754, 46697, 14723, 13315]
})

# Créer la carte
carte = folium.Map(
    location=[45.7, 1.5],
    zoom_start=9
)

# Ajouter un cercle pour chaque ville
for idx, row in villes.iterrows():   # .iterrows() permet d'itérer sur les lignes d'un df. Renvoie l'index de la ligne, et la ligne
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=row['population'] / 5000,  # Taille proportionnelle à la population. Ici on divise par 5000 mais c'est à adapter
        popup=f"{row['ville']}<br>Population: {row['population']:,}",
        color='crimson',    #couleur des cercles
        fill=True,          # cercles pleins
        fillColor='crimson',  # couleur du remplissage des cercles
        fillOpacity=0.6       # transparence du remplissage du cercle
    ).add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_012f771a5d16d5bc00daf0f5abab8ec6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_012f771a5d16d5bc00daf0f5abab8ec6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_012f771a5d16d5bc00daf0f5abab8ec6 = L.map(
#                 &quot;map_012f771a5d16d5bc00daf0f5abab8ec6&quot;,
#                 {
#                     center: [45.7, 1.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23f9d54943a7a0ccb9d1b5a6a57235a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23f9d54943a7a0ccb9d1b5a6a57235a1.addTo(map_012f771a5d16d5bc00daf0f5abab8ec6);
#
#
#             var circle_marker_891db4fdd5629a1c4b65eaa329cb6a7e = L.circleMarker(
#                 [45.85, 1.25],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.9508, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_012f771a5d16d5bc00daf0f5abab8ec6);
#
#
#         var popup_6fe3049c7a4bee06b53b0ac29e0e0d80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91c6491a90ba2ea156e43bc5118939bd = $(`&lt;div id=&quot;html_91c6491a90ba2ea156e43bc5118939bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Limoges&lt;br&gt;Population: 129,754&lt;/div&gt;`)[0];
#                 popup_6fe3049c7a4bee06b53b0ac29e0e0d80.setContent(html_91c6491a90ba2ea156e43bc5118939bd);
#
#
#
#         circle_marker_891db4fdd5629a1c4b65eaa329cb6a7e.bindPopup(popup_6fe3049c7a4bee06b53b0ac29e0e0d80)
#         ;
#
#
#
#
#             var circle_marker_7ffe6caffb988c52a35c95f64652f823 = L.circleMarker(
#                 [45.1586, 1.5339],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.3394, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_012f771a5d16d5bc00daf0f5abab8ec6);
#
#
#         var popup_184c10f66b4cfea54b951fb323b21590 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8295c95174ce442d15ad094dacb52b70 = $(`&lt;div id=&quot;html_8295c95174ce442d15ad094dacb52b70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brive-la-Gaillarde&lt;br&gt;Population: 46,697&lt;/div&gt;`)[0];
#                 popup_184c10f66b4cfea54b951fb323b21590.setContent(html_8295c95174ce442d15ad094dacb52b70);
#
#
#
#         circle_marker_7ffe6caffb988c52a35c95f64652f823.bindPopup(popup_184c10f66b4cfea54b951fb323b21590)
#         ;
#
#
#
#
#             var circle_marker_0869e153d29318135688c5cb46de21aa = L.circleMarker(
#                 [45.2655, 1.7711],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.9446, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_012f771a5d16d5bc00daf0f5abab8ec6);
#
#
#         var popup_d6dd23a45ebe261879f0aa5971ce367b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_224345e58ab6c91e34a9861dd86ad3a2 = $(`&lt;div id=&quot;html_224345e58ab6c91e34a9861dd86ad3a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tulle&lt;br&gt;Population: 14,723&lt;/div&gt;`)[0];
#                 popup_d6dd23a45ebe261879f0aa5971ce367b.setContent(html_224345e58ab6c91e34a9861dd86ad3a2);
#
#
#
#         circle_marker_0869e153d29318135688c5cb46de21aa.bindPopup(popup_d6dd23a45ebe261879f0aa5971ce367b)
#         ;

# %% [markdown]
# ### Intégration avec GeoPandas
#
# **Important :** Folium nécessite que les données soient en projection **EPSG:4326** (WGS84)

# %%
import geopandas as gpd
import folium


# Charger les départements français
departements = gpd.read_file("DATA/departements.geojson")

# Vérifier et convertir le CRS si nécessaire
print(f"CRS actuel : {departements.crs}")

if departements.crs != 'EPSG:4326':
    departements = departements.to_crs(epsg=4326)
    print("Converti en EPSG:4326")

# Filtrer pour la Nouvelle-Aquitaine
nouvelle_aquitaine = departements[departements['nom'].isin([
    'Corrèze', 'Creuse', 'Haute-Vienne', 'Charente', 'Charente-Maritime',
    'Deux-Sèvres', 'Vienne', 'Dordogne', 'Gironde', 'Landes',
    'Lot-et-Garonne', 'Pyrénées-Atlantiques'
])]

# Créer la carte
carte = folium.Map(
    location=[45.5, 0.5],
    zoom_start=7
)

# Ajouter les polygones des départements
folium.GeoJson(                     # Dessiner à partir d'un GeoJson
    nouvelle_aquitaine,             # Nom de la variable qui contient le GeoJson
    name='Départements',            # Nom de la couche
    style_function=lambda x: {      # On appelle une fonction qui est appliquée à chaque élément du GeoJson
        'fillColor': 'lightblue',   # Couleur de remplissage
        'color': 'darkblue',        # Couleur des bordures
        'weight': 2,               # Epaisseur du trait
        'fillOpacity': 0.5         # Transparence du remplissage
    },
    tooltip=folium.GeoJsonTooltip(fields=['nom'], aliases=['Département :']) # On fait un tooltip pour chaque élément du GeoJson, fields = champ à lire ; aliases= texte à mettre devant les fields
).add_to(carte)

carte
# Out:
# CRS actuel : EPSG:4326
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7cb07d175bef0ac0adf21ccf3080211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7cb07d175bef0ac0adf21ccf3080211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7cb07d175bef0ac0adf21ccf3080211 = L.map(
#                 &quot;map_a7cb07d175bef0ac0adf21ccf3080211&quot;,
#                 {
#                     center: [45.5, 0.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd6775d8301d1f1f4845831271ce16be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd6775d8301d1f1f4845831271ce16be.addTo(map_a7cb07d175bef0ac0adf21ccf3080211);
#
#
#         function geo_json_05262364f2a7c851deacc81806607606_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkblue&quot;, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_05262364f2a7c851deacc81806607606_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_05262364f2a7c851deacc81806607606 = L.geoJson(null, {
#                 onEachFeature: geo_json_05262364f2a7c851deacc81806607606_onEachFeature,
#
#                 style: geo_json_05262364f2a7c851deacc81806607606_styler,
#             ...{
# }
#         });
#
#         function geo_json_05262364f2a7c851deacc81806607606_add (data) {
#             geo_json_05262364f2a7c851deacc81806607606
#                 .addData(data);
#         }
#             geo_json_05262364f2a7c851deacc81806607606_add({&quot;bbox&quot;: [-1.79235, 42.77752, 2.61157, 47.17576], &quot;features&quot;: [{&quot;bbox&quot;: [-0.46315, 45.19163, 0.94699, 46.14005], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.10294, 45.96966], [-0.09758, 45.97113], [-0.0948, 45.97245], [-0.08743, 45.975], [-0.08194, 45.97804], [-0.07652, 45.97959], [-0.07527, 45.98038], [-0.0724, 45.97833], [-0.07209, 45.98018], [-0.06656, 45.98071], [-0.06267, 45.98164], [-0.06201, 45.97972], [-0.0603, 45.98188], [-0.06157, 45.98302], [-0.05837, 45.98682], [-0.05296, 45.98847], [-0.04777, 45.9893], [-0.04324, 45.99034], [-0.04505, 45.99354], [-0.04406, 45.99451], [-0.03815, 45.99242], [-0.03874, 45.99421], [-0.04098, 45.99498], [-0.04087, 45.99858], [-0.04457, 45.99877], [-0.04723, 45.99925], [-0.04776, 45.99811], [-0.05198, 45.9983], [-0.05474, 45.99806], [-0.05735, 45.99894], [-0.0543, 46.00117], [-0.05193, 46.00163], [-0.04889, 46.00305], [-0.0479, 46.00437], [-0.04951, 46.00852], [-0.04856, 46.01038], [-0.04559, 46.01342], [-0.04536, 46.01981], [-0.04353, 46.02085], [-0.03783, 46.02078], [-0.03078, 46.02193], [-0.03067, 46.02242], [-0.02741, 46.02456], [-0.02567, 46.02635], [-0.02551, 46.02865], [-0.02145, 46.02887], [-0.02233, 46.03124], [-0.02656, 46.03475], [-0.02957, 46.03594], [-0.03204, 46.03751], [-0.03254, 46.04016], [-0.03441, 46.04183], [-0.03767, 46.04392], [-0.03821, 46.05039], [-0.0395, 46.05311], [-0.03428, 46.05484], [-0.032, 46.05592], [-0.02356, 46.05672], [-0.019, 46.05597], [-0.01818, 46.05495], [-0.01308, 46.05654], [-0.01123, 46.05564], [-0.00845, 46.05569], [-0.00533, 46.05522], [-0.00088, 46.05553], [0.00083, 46.05634], [0.00341, 46.0594], [0.00515, 46.05949], [0.00928, 46.05831], [0.01283, 46.05685], [0.01927, 46.05285], [0.02075, 46.05441], [0.02515, 46.05594], [0.0281, 46.05802], [0.02886, 46.06007], [0.0327, 46.06684], [0.03481, 46.06617], [0.03703, 46.06703], [0.03768, 46.07006], [0.04006, 46.06866], [0.04243, 46.06803], [0.04578, 46.06977], [0.04954, 46.06926], [0.05621, 46.0707], [0.06109, 46.07202], [0.06258, 46.07269], [0.06, 46.07438], [0.05798, 46.07501], [0.05532, 46.0768], [0.05201, 46.07831], [0.0508, 46.07941], [0.05544, 46.08139], [0.05472, 46.08331], [0.05651, 46.0852], [0.05967, 46.08706], [0.06337, 46.08848], [0.06636, 46.0912], [0.07107, 46.09283], [0.07297, 46.0939], [0.07858, 46.09437], [0.08119, 46.0937], [0.08457, 46.09337]

# %% [markdown]
# ## Carte qui affiche des couleurs différentes pour chaque département :

# %%
# Liste de couleurs disponibles
couleurs = ['red', 'green', 'orange', 'blue', 'purple', 'pink', 'darkred', 'darkgreen', 'darkblue', 'cadetblue', 'lightred', 'beige']

# Créer automatiquement le dictionnaire nom -> couleur
couleurs_dept = {
    nom: couleurs[i] 
    for i, nom in enumerate(nouvelle_aquitaine['nom'])
} # { clé: valeur for variable in liste }
# enumerate renvoie des paires Index - Valeur
# à chaque itération on a i = index , nom = nom dans le gdf, et on récupère la couleur dans la liste à l'index correspondant au gdf


carte = folium.Map(location=[45.8, 1.8], zoom_start=6)

folium.GeoJson(
    nouvelle_aquitaine,
    style_function=lambda x: {
        'fillColor': couleurs_dept.get(x['properties']['nom'], 'gray'),
        'color': 'black',
        'weight': 2,
        'fillOpacity': 0.6
    },
    tooltip=folium.GeoJsonTooltip(fields=['nom'], aliases=['Département :'])
).add_to(carte)


# EXPLICATION DE couleurs_dept.get(x['properties']['nom'], 'gray')
# .get renvoie une valeur à partir d'une clé de dictionnaire, ou une valeur de base si on ne trouve pas la clé.
# x['properties']['nom'] renvoie chaque nom de département, puisqu'on opère un lambda x: pour parcourir le gdf
# en somme, on cherche la valeur (couleur ici) dans le dictionnaire qu'on a créé au dessus à partir des noms de départements du gdf.
# Et comme le nom du département change à chaque itération grâce à style_function, on peut appliquer des couleurs/paramètres adaptés à nos données 
carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_371bbd94a082b9c596bea9bdd5194503 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_371bbd94a082b9c596bea9bdd5194503&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_371bbd94a082b9c596bea9bdd5194503 = L.map(
#                 &quot;map_371bbd94a082b9c596bea9bdd5194503&quot;,
#                 {
#                     center: [45.8, 1.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3cfdd9dd1900b7e02b1ea200210fe1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3cfdd9dd1900b7e02b1ea200210fe1f.addTo(map_371bbd94a082b9c596bea9bdd5194503);
#
#
#         function geo_json_9c62afc1127b44056eb7b84202ea3974_styler(feature) {
#             switch(feature.id) {
#                 case &quot;17&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;23&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;24&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;33&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;47&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;64&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;79&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;cadetblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 case &quot;86&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;lightred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;beige&quot;, &quot;fillOpacity&quot;: 0.6, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_9c62afc1127b44056eb7b84202ea3974_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_9c62afc1127b44056eb7b84202ea3974 = L.geoJson(null, {
#                 onEachFeature: geo_json_9c62afc1127b44056eb7b84202ea3974_onEachFeature,
#
#                 style: geo_json_9c62afc1127b44056eb7b84202ea3974_styler,
#             ...{
# }
#         });
#
#         function geo_json_9c62afc1127b44056eb7b84202ea3974_add (data) {
#             geo_json_9c62afc1127b44056eb7b84202ea3974
#                 .addData(data);
#         }
#             geo_json_9c62afc1127b44056eb7b84202ea3974_add({&quot;bbox&quot;: [-1.79235, 42.77752, 2.61157, 47.17576], &quot;features&quot;: [{&quot;bbox&quot;: [-0.46315, 45.19163, 0.94699, 46.14005], &quot;geometry&quot;:

# %% [markdown]
# # EXERCICE 3
#
# Faites la même chose sur une autre région.
# 1 - filtre
# 2 - dictionnaire de couleurs
# 3 - création de carte interactive qui affiche le nom des départements au survol

# %% [markdown]
# ### Cartes choroplèthes (cartes de chaleur par zones)
#
# Les cartes choroplèthes colorent les zones selon une valeur numérique (population, densité, etc.)

# %%
# Charger les départements avec leurs populations
# (Pour l'exemple, on va ajouter des données fictives)
departements_data = nouvelle_aquitaine.copy()

# Données de population
population_dict = {
    'Corrèze':              241041,
    'Creuse':               115406,
    'Haute-Vienne':         373138,
    'Charente':             352712,
    'Charente-Maritime':    677063,
    'Deux-Sèvres':          375205,
    'Vienne':               438156,
    'Dordogne':             418922,
    'Gironde':             1705851,
    'Landes':               437955,
    'Lot-et-Garonne':       334441,
    'Pyrénées-Atlantiques': 711995,
}

departements_data['population'] = departements_data['nom'].map(population_dict)   #.map permet d'ajouter les données en faisant une jointure sur le nom

# Créer la carte choroplèthe
carte = folium.Map(
    location=[45.5, 0.5],
    zoom_start=6
)

folium.Choropleth(
    geo_data=departements_data,          # Contour
    name='Population',                   
    data=departements_data,              # Couleur de Choroplèthe
    columns=['nom', 'population'],       # Colonnes à intégrer dans la carte
    key_on='feature.properties.nom',     # Sur quoi base-t-on l'association entre "nom" et "population"
    fill_color='YlOrRd',  # Palette de couleurs (Yellow-Orange-Red)
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population'
).add_to(carte)

# Ajouter les tooltips sur une deuxième couche transparente
folium.GeoJson(
    departements_data,
    style_function=lambda x: {'fillColor': 'transparent', 'color': 'transparent'}, # Couche transparente
    tooltip=folium.GeoJsonTooltip(
        fields=['nom', 'population'],
        aliases=['Département :', 'Population :'],
        localize=True                               #formatage des nombres selon la locale user : ici en français je suppose
    )
).add_to(carte)

# Ajouter un contrôle de couches
folium.LayerControl().add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c81549e332b5ea8e065ad1673e7999d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c81549e332b5ea8e065ad1673e7999d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c81549e332b5ea8e065ad1673e7999d5 = L.map(
#                 &quot;map_c81549e332b5ea8e065ad1673e7999d5&quot;,
#                 {
#                     center: [45.5, 0.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74ab104d9d9b00e3a9f56e7f12b0b173 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74ab104d9d9b00e3a9f56e7f12b0b173.addTo(map_c81549e332b5ea8e065ad1673e7999d5);
#
#
#             var choropleth_de06820415521ae943b78151bb9537df = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_a2fc5adc7418ee585ad40388fcf92498_styler(feature) {
#             switch(feature.id) {
#                 case &quot;17&quot;: case &quot;20&quot;: case &quot;23&quot;: case &quot;47&quot;: case &quot;79&quot;: case &quot;87&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;18&quot;: case &quot;64&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;24&quot;: case &quot;40&quot;: case &quot;86&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a2fc5adc7418ee585ad40388fcf92498_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a2fc5adc7418ee585ad40388fcf92498 = L.geoJson(null, {
#                 onEachFeature: geo_json_a2fc5adc7418ee585ad40388fcf92498_onEachFeature,
#
#                 style: geo_json_a2fc5adc7418ee585ad40388fcf92498_styler,
#             ...{
# }
#         });
#
#         function geo_json_a2fc5adc7418ee585ad40388fcf92498_add (data) {
#             geo_json_a2fc5adc7418ee585ad40388fcf92498
#                 .addData(data);
#         }
#             geo_json_a2fc5adc7418ee585ad40388fcf92498_add({&quot;bbox&quot;: [-1.79235, 42.77752, 2.61157, 47.17576], &quot;features&quot;: [{&quot;bbox&quot;: [-0.46315, 45.19163, 0.94699, 46.14005], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.10294, 45.96966], [-0.09758, 45.97113], [-0.0948, 45.97245], [-0.08743, 45.975], [-0.08194, 45.97804], [-0.07652, 45.97959], [-0.07527, 45.98038], [-0.0724, 45.97833], [-0.07209, 45.98018], [-0.06656, 45.98071], [-0.06267, 45.98164], [-0.06201, 45.97972], [-0.0603, 45.98188], [-0.06157, 45.98302], [-0.05837, 45.98682], [-0.05296, 45.98847], [-0.04777, 45.9893], [-0.04324, 45.99034], [-0.04505, 45.99354], [-0.04406, 45.99451], [-0.03815, 45.99242], [-0.03874, 45.99421], [-0.04098, 45.99498], [-0.04087, 45.99858], [-0.04457, 45.99877], [-0.04723, 45.99925], [-0.04776, 45.99811], [-0.05198, 45.9983], [-0.05474, 45.99806], [-0.05735, 45.99894], [-0.0543, 46.00117], [-0.05193, 46.00163], [-0.04889, 46.00305], [-0.0479, 46.00437], [-0.04951, 46.00852], [-0.04856, 46.01038], [-0.04559, 46.01342], [-0.04536, 46.01981], [-0.04353, 46.02085], [-0.03783, 46.02078], [-0.03078, 46.02193], [-0.03067, 46.02242], [-0.02741, 46.02456], [-0.02567, 46.02635], [-0.02551, 46.02865], [-0.02145, 46.02887], [-0.02233, 46.03124], [-0.02656, 46.03475], [-0.02957, 46.03594], [

# %% [markdown]
# ### Intégration de choroplèhtes par classe avec matplotlib, mapclassify et folium
# On ne peut pas nativement faire une choroplèthe par classes sous folium, et c'est assez nul. Une option pour le contourner et avoir un rendu dynamique et plutôt sympa, c'est d'utiliser la fonction explore de matplotlib. Elle construira toute seul la carte grâce à Folium, avec des arguments que vous connaissez déjà :

# %%
departements_data
# Out:
#    code                   nom  \
# 17   16              Charente
# 18   17     Charente-Maritime
# 20   19               Corrèze
# 23   23                Creuse
# 24   24              Dordogne
# 33   33               Gironde
# 40   40                Landes
# 47   47        Lot-et-Garonne
# 64   64  Pyrénées-Atlantiques
# 79   79           Deux-Sèvres
# 86   86                Vienne
# 87   87          Haute-Vienne
#
#                                              geometry  population
# 17  POLYGON ((-0.10294 45.96966, -0.09758 45.97113...      352712
# 18  MULTIPOLYGON (((-1.11427 45.95173, -1.1163 45....      677063
# 20  POLYGON ((1.89873 45.69828, 1.89931 45.69828, ...      241041
# 23  POLYGON ((2.16779 46.42407, 2.17254 46.42228, ...      115406
# 24  POLYGON ((0.62974 45.71457, 0.63094 45.71328, ...      418922
# 33  MULTIPOLYGON (((-1.23902 44.59278, -1.23583 44...     1705851
# 40  POLYGON ((-0.24284 43.58498, -0.24346 43.58357...      437955
# 47  POLYGON ((0.29733 44.76228, 0.30032 44.75987, ...      334441
# 64  POLYGON ((-0.24284 43.58498, -0.24233 43.58342...      711995
# 79  POLYGON ((-0.89196 46.97582, -0.88799 46.97544...      375205
# 86  POLYGON ((-0.10212 47.0648, -0.10516 47.07112,...      438156
# 87  POLYGON ((0.82343 46.12858, 0.82634 46.12871, ...      373138

# %%
pip install mapclassify
# Out:
# Requirement already satisfied: mapclassify in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: networkx>=3.2 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from mapclassify) (3.4.2)
# Requirement already satisfied: numpy>=1.26 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from mapclassify) (2.1.3)
# Requirement already satisfied: pandas>=2.1 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from mapclassify) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.4 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from mapclassify) (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from pandas>=2.1->mapclassify) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.4->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maritp02\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.4->mapclassify) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
departements_data = nouvelle_aquitaine.copy()
#On va juste remettre les vraies données avec une jointure vu qu'on a vu la méthdode map 
df = pd.read_csv("DATA/donnees_departements.csv", sep=";", encoding="utf-8")
departements_data = departements_data.merge(df, left_on="code", right_on = "DEP")


# On est en France, on calcule les superficies en Lambert :
departements_data = departements_data.to_crs(2154)
departements_data["superficie"] = departements_data.geometry.area / 1_000_000
departements_data["densite"]=departements_data["PTOT"]/departements_data["superficie"]


# On utilise la fonction pd.qcut  :
departements_data["classes_densite"]= pd.qcut(
    departements_data["densite"],
    4,
    labels=["Q1","Q2","Q3","Q4"]
)


#On projette avec Folium, on repasse en pseudo-mercator
departements_data = departements_data.to_crs(4326)


# Fonction explore
m = departements_data.explore(
    column='classes_densite',     
    tiles="CartoDB positron",
    legend=True,           
    edgecolor='black',     
    linewidth=0.8,         
    cmap='viridis_r',       
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac2abb10cc459304d876ad906ec1e25a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend classes_densite&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;classes_densite&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fde725&#x27;&gt;&lt;/span&gt;Q1&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#35b779&#x27;&gt;&lt;/span&gt;Q2&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#31688e&#x27;&gt;&lt;/span&gt;Q3&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#440154&#x27;&gt;&lt;/span&gt;Q4&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac2abb10cc459304d876ad906ec1e25a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac2abb10cc459304d876ad906ec1e25a = L.map(
#                 &quot;map_ac2abb10cc459304d876ad906ec1e25a&quot;,
#                 {
#                     center: [44.97664, 0.40961000000000003],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ac2abb10cc459304d876ad906ec1e25a);
#
#
#
#
#
#             var tile_layer_3d7b7facd272ad4c7ce92961ed7cdec6 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d7b7facd272ad4c7ce92961ed7cdec6.addTo(map_ac2abb10cc459304d876ad906ec1e25a);
#
#
#             map_ac2abb10cc459304d876ad906ec1e25a.fitBounds(
#                 [[42.77752000000001, -1.7923499999999999], [47.17576, 2.61157]],
#                 {}
#             );
#
#
#         function geo_json_17256c7e1b775a081e2f0f1f9f418e3c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#35b779&quot;, &quot;fillColor&quot;: &quot;#35b779&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fil

# %% [markdown]
# ### Carte de chaleur (HeatMap) avec points
#
# Les HeatMap permettent de visualiser la concentration de points.

# %%
from folium.plugins import HeatMap
import numpy as np

# Générer des points aléatoires autour de Limoges (pour l'exemple)
np.random.seed(42)
n_points = 200

# Coordonnées centrées sur Limoges avec un peu de variation
lats = np.random.normal(45.85, 0.05, n_points)
lons = np.random.normal(1.25, 0.05, n_points)

# Créer une liste de coordonnées
heat_data = [[lat, lon] for lat, lon in zip(lats, lons)]

# Créer la carte
carte = folium.Map(
    location=[45.85, 1.25],
    zoom_start=12
)

# Ajouter la heatmap
HeatMap(
    heat_data,
    radius=15,
    blur=25,
    max_zoom=13
).add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed0d90a4d6d12722b5cd20e364c05258 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed0d90a4d6d12722b5cd20e364c05258&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed0d90a4d6d12722b5cd20e364c05258 = L.map(
#                 &quot;map_ed0d90a4d6d12722b5cd20e364c05258&quot;,
#                 {
#                     center: [45.85, 1.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eda112f1f83098065b2acdc0d0846831 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eda112f1f83098065b2acdc0d0846831.addTo(map_ed0d90a4d6d12722b5cd20e364c05258);
#
#
#             var heat_map_0778cc4831db058c36137d1e7cccd5d6 = L.heatLayer(
#                 [[45.87483570765056, 1.2678893680174141], [45.84308678494144, 1.2780392263184117], [45.882384426905034, 1.3041525621587637], [45.9261514928204, 1.3026901026017452], [45.83829233126384, 1.1811165316021455], [45.838293152152545, 1.203108748004244], [45.92896064077537, 1.275751763360433], [45.88837173645765, 1.2756892975456104], [45.826526280703256, 1.2757523843153025], [45.8771280021793, 1.442636574532736], [45.82682911535938, 1.2785445255346584], [45.82671351232149, 1.30677828200903], [45.862098113578305, 1.29770008817466], [45.754335987767114, 1.28256956256529], [45.76375410837435, 1.2342365377679827], [45.82188562353795, 1.2879484610246634], [45.79935844398328, 1.2113587392731213], [45.865712366629765, 1.2381590696629996], [45.80459879622394, 1.2257318226085447], [45.77938481493324, 1.254093706969316], [45.92328243844608, 1.3657329283336754], [45.83871118497567, 1.1566367403704125], [45.8533764102344, 1.2843130095187256], [45.778762590689325, 1.1693642064405174], [45.822780863773744, 1.2264034067105283], [45.8555461294855, 1.3044475298483682], [45.79245032112889, 1.2532140009547732], [45.868784900917284, 1.1961127611035347], [45.819968065504064, 1.2142348145370017], [45.835415312510335, 1.2839798874467339], [45.81991466938853, 1.2134816684141432], [45.94261390922545, 1.2608229294790987], [45.849325138763106, 1.2522785919951906], [45.797114453552204, 1.2174199826197092], [45.89112724560516, 1.3571972044662663], [45.78895781750145, 1.2816959511159005], [45.86044317975024, 1.1487428706671197], [45.75201649380601, 1.2593227157384714], [45.78359069755508, 1.2169106767615805], [45.859843061793455, 1.2926216667398112], [45.88692332899977, 1.210373963078365], [45.8585684140595, 1.244263177926655], [45.84421758588059, 1.2752493639490228], [45.83494481522054, 1.2932877597085062], [45.77607390048163, 1.1899851796472112], [45.814007789580266, 1.2332749382079526], [45.826968061452014, 1.2262527344419523], [45.902856111310946, 1.2173335383713144], [45.867180914478425, 1.3382727120140547], [45.761847992231864, 1.2702490855480477], [45.86620419846974, 1.1869558022832478], [45.830745885979184, 1.2958930973527387], [45.816153899984705, 1.3561078098506316], [45.88058381444205, 1.3016232630275573], [45.9015499761248, 1.1740315017022993], [45.89656400595581, 1.2257882963566875], [45.80803912383887, 1.3133455574593311], [45.83453938120744, 1.214616526719061], [45.86656317157018, 1.2721909714073114], [45.89877725635612, 1.2887317026714669], [45.82604128810774, 1.2036534764210958], [45.84071705116681, 1.24702373219691], [45.7946832512997, 1.0879366329965463], [45.79018966879597, 1.1987806179332856], [45.89062629111971, 1.237371592430342], [45.917812001428544, 1.1876108409017576], [45.846399493920984, 1.3316205651965818], [45.9001766448946, 1.1784929311019683], [45.86808180125238, 1.2279977756651508], [45.81774401226974, 1.2565370288643045], [45.86806978027542, 1.3220636644533057], [45.9269018283233, 1.178206892441028], [45.8482086980445, 1.308158187607748], [45.9282321827907, 1.2505116530509794], [45.71901274479551, 1.2009245674476023], [45.89109512521876, 1.2731051737131636], [45.85435235341191, 1.2599529847786735], [45.83504963247671, 1.2199891561420602], [45.854588038826776, 1.253490104249501], [45.750621554269955, 1.230734320156912], [45.83901640560813, 1.2556758672625623], [45.86785562857559, 1.2831065337260523], [45.92389470223708, 1.3293008408072675], [45.82408648908632, 1.1881092250586576], [45.80957531985534, 1.3566516687328134], [45.824912147820775, 1.1523956100238748], [45.895770105885106, 1.242410745248221], [45.86643755548299, 1.279415860324229], [45.82351198981165, 1.2640495933867517], [45.87

# %% [markdown]
# # EXERCICE 4
# Créez une HeatMap qui représente la localisation des restaurants ou commerces d'une ville. Vous pouvez utiliser des coordonnées fictives ou réelles si vous en avez.

# %%
# Votre code ici

# %% [markdown]
# ## Tracer des lignes et des trajets

# %%
# Trajet fictif entre plusieurs villes du Limousin
trajet = [
    [45.85, 1.25],      # Limoges
    [45.1586, 1.5339],  # Brive
    [45.2655, 1.7711],  # Tulle
    [46.1702, 1.8716]   # Guéret
]

carte = folium.Map(
    location=[45.7, 1.5],
    zoom_start=9
)

# Ajouter une ligne
folium.PolyLine(
    trajet,
    color='red',
    weight=4,
    opacity=0.8,
    popup='Trajet Limousin'
).add_to(carte)

# Ajouter des marqueurs aux extrémités
for idx, point in enumerate(trajet):
    folium.Marker(
        point,
        popup=f'Étape {idx + 1}',
        icon=folium.Icon(color='red', icon='flag')
    ).add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_084f974e78fa41e64d1f0a1eba09ded5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_084f974e78fa41e64d1f0a1eba09ded5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_084f974e78fa41e64d1f0a1eba09ded5 = L.map(
#                 &quot;map_084f974e78fa41e64d1f0a1eba09ded5&quot;,
#                 {
#                     center: [45.7, 1.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f835deec2c87164379a88eca5992168e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f835deec2c87164379a88eca5992168e.addTo(map_084f974e78fa41e64d1f0a1eba09ded5);
#
#
#             var poly_line_04af854dba76f212c008bd05fc7228cd = L.polyline(
#                 [[45.85, 1.25], [45.1586, 1.5339], [45.2655, 1.7711], [46.1702, 1.8716]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_084f974e78fa41e64d1f0a1eba09ded5);
#
#
#         var popup_e62c4958d0a4b57fc709b18589b91915 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f45854eb70589a5fa1f5075e809ab103 = $(`&lt;div id=&quot;html_f45854eb70589a5fa1f5075e809ab103&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trajet Limousin&lt;/div&gt;`)[0];
#                 popup_e62c4958d0a4b57fc709b18589b91915.setContent(html_f45854eb70589a5fa1f5075e809ab103);
#
#
#
#         poly_line_04af854dba76f212c008bd05fc7228cd.bindPopup(popup_e62c4958d0a4b57fc709b18589b91915)
#         ;
#
#
#
#
#             var marker_fc56ce30923cbb792f25e9c186f3eb7e = L.marker(
#                 [45.85, 1.25],
#                 {
# }
#             ).addTo(map_084f974e78fa41e64d1f0a1eba09ded5);
#
#
#             var icon_a56877a7f894840e52f071dad6720390 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4fa8c6f0081a1d1f8ab15253ab954d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf7d673d66264622de01e8a87bfd5573 = $(`&lt;div id=&quot;html_bf7d673d66264622de01e8a87bfd5573&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Étape 1&lt;/div&gt;`)[0];
#                 popup_4fa8c6f0081a1d1f8ab15253ab954d6a.setContent(html_bf7d673d66264622de01e8a87bfd5573);
#
#
#
#         marker_fc56ce30923cbb792f25e9c186f3eb7e.bindPopup(popup_4fa8c6f0081a1d1f8ab15253ab954d6a)
#         ;
#
#
#
#
#                 marker_fc56ce30923cbb792f25e9c186f3eb7e.setIcon(icon_a56877a7f894840e52f071dad6720390);
#
#
#             var marker_17de8f5adb7eaee9b1ea2925699c281e = L.marker(
#                 [45.1586, 1.5339],
#                 {
# }
#             ).addTo(map_084f974e78fa41e64d1f0a1eba09ded5);
#
#
#             var icon_6cf90e4ecccfb418202d426fc3969e4b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_97ed9b95324cb315cae85da38d06e05f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9018edf29fa17e4d1efb2b8f9b0e2a4f = $(`&lt;div id=&quot;html_9018edf29fa17e4d1efb2b8f9b0e2a4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Étape 2&lt;/div&gt;`)[0];
#                 popup_97ed9b95324cb315cae85da38d06e05f.setContent(html_9018edf29fa17e4d1efb2b8f9b0e2a4f);
#
#
#
#         marker_17de8f5adb7eaee9b1ea2925699c281e.bindPopup(popup_97ed9b95324cb315cae85da38d06e05f)
#         ;
#
#
#
#
#                 marker_17de8f5adb7eaee9b1ea2925699c281e.setIcon(icon_6cf90e4ecccfb418202d426fc3969e4b);
#
#
#             var marker_c6febafe

# %% [markdown]
# ## Popups HTML personnalisés
#
# Vous pouvez créer des popups avec du HTML pour un rendu plus riche.

# %%
carte = folium.Map(
    location=[45.836286250961614, 1.2674356978313563],
    zoom_start=13
)

# Créer un popup HTML personnalisé
html_popup = """
<div style="font-family: Arial; width: 250px;">
    <h3 style="color: #2c5aa0;">Gare de Limoges-Bénédictins</h3>
    <img src="https://upload.wikimedia.org/wikipedia/commons/4/4e/Gare_de_Limoges_B%C3%A9n%C3%A9dictins.jpg" 
         style="width: 100%; border-radius: 5px;">
    <p><b>Type :</b> Gare ferroviaire</p>
    <p><b>Architecture :</b> Style Art déco</p>
    <p><b>Année :</b> 1929</p>
</div>
"""

iframe = folium.IFrame(html_popup, width=270, height=350)
popup = folium.Popup(iframe, max_width=270)

folium.Marker(
    location=[45.836286250961614, 1.2674356978313563],
    popup=popup,
    icon=folium.Icon(color='blue', icon='train', prefix='fa')
).add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5fa35a8daeeda2a40470809c374631a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5fa35a8daeeda2a40470809c374631a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5fa35a8daeeda2a40470809c374631a = L.map(
#                 &quot;map_b5fa35a8daeeda2a40470809c374631a&quot;,
#                 {
#                     center: [45.836286250961614, 1.2674356978313563],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3108167b25e6177c446906a45b5c5097 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3108167b25e6177c446906a45b5c5097.addTo(map_b5fa35a8daeeda2a40470809c374631a);
#
#
#             var marker_57bc64bbf2b7c4d6cdf7951dc8d2c578 = L.marker(
#                 [45.836286250961614, 1.2674356978313563],
#                 {
# }
#             ).addTo(map_b5fa35a8daeeda2a40470809c374631a);
#
#
#             var icon_1f1a7711b98526c8c50484f3dbde0c56 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_754e071fd9088d3bbe620d418397a28c = L.popup({
#   &quot;maxWidth&quot;: 270,
# });
#
#
#
#                 var i_frame_ebf392721a461a605bcdef1dd25bb4cd = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;270&quot; style=&quot;border:none !important;&quot; height=&quot;350&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_754e071fd9088d3bbe620d418397a28c.setContent(i_frame_ebf392721a461a605bcdef1dd25bb4cd);
#
#
#
#         marker_57bc64bbf2b7c4d6cdf7951dc8d2c578.bindPopup(popup_754e071fd9088d3bbe620d418397a28c)
#         ;
#
#
#
#
#                 marker_57bc64bbf2b7c4d6cdf7951dc8d2c578.setIcon(icon_1f1a7711b98526c8c50484f3dbde0c56);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Exercice 5 :
#
# Créez une carte interactive complète d'une région qui contient :
# 1. Au moins 5 marqueurs avec des popups personnalisés (HTML)
# 2. Un fond de carte de votre choix
# 3. Une couche de polygones (départements ou communes)
# 4. Un trajet entre plusieurs points
#
# On sauvegardera ensuite votre carte en HTML pour pouvoir la partager.

# %%
# Votre code ici

# %% [markdown]
# ## Sauvegarder une carte en HTML
#
# Pour partager votre carte ou l'intégrer dans un site web :

# %%
# Créer une carte simple
carte = folium.Map(
    location=[45.85, 1.25],
    zoom_start=13
)

folium.Marker(
    location=[45.81772041276887, 1.23296439442943265],
    popup='Vous êtes ici',
    icon=folium.Icon(color='red', icon='star')
).add_to(carte)

# Sauvegarder en HTML
carte.save('carte_interactive.html')

print("Carte sauvegardée dans 'carte_interactive.html'")
# Out:
# Carte sauvegardée dans 'carte_interactive.html'

# %% [markdown]
# ## Plugins avancés de Folium
#
# Folium propose de nombreux plugins pour enrichir vos cartes.

# %%
from folium.plugins import MiniMap, Fullscreen, MousePosition, MeasureControl

carte = folium.Map(
    location=[45.85, 1.25],
    zoom_start=13
)

# Ajouter une mini-carte dans le coin
minimap = MiniMap(toggle_display=True)
carte.add_child(minimap)

# Bouton plein écran
Fullscreen().add_to(carte)

# Afficher les coordonnées de la souris
MousePosition().add_to(carte)

# Outil de mesure de distance
MeasureControl().add_to(carte)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_204de276d113ca3fdfba20fe3a326bf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_204de276d113ca3fdfba20fe3a326bf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_204de276d113ca3fdfba20fe3a326bf8 = L.map(
#                 &quot;map_204de276d113ca3fdfba20fe3a326bf8&quot;,
#                 {
#                     center: [45.85, 1.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0694a91fbee71bb749d386b15cf835b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0694a91fbee71bb749d386b15cf835b.addTo(map_204de276d113ca3fdfba20fe3a326bf8);
#
#
#             var tile_layer_2d4f5551304b6fc05152beded0e348f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detect_retina&quot;: false, &quot;max_native_zoom&quot;: 19, &quot;max_zoom&quot;: 19, &quot;min_zoom&quot;: 0, &quot;no_wrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_6b367afe67c01b93c506ce2e54e4be56 = new L.Control.MiniMap(
#                 tile_layer_2d4f5551304b6fc05152beded0e348f3,
#                 {
#   &quot;position&quot;: &quot;bottomright&quot;,
#   &quot;width&quot;: 150,
#   &quot;height&quot;: 150,
#   &quot;collapsedWidth&quot;: 25,
#   &quot;collapsedHeight&quot;: 25,
#   &quot;zoomLevelOffset&quot;: -5,
#   &quot;centerFixed&quot;: false,
#   &quot;zoomAnimation&quot;: false,
#   &quot;toggleDisplay&quot;: true,
#   &quot;autoToggleDisplay&quot;: false,
#   &quot;minimized&quot;: false,
# }
#             );
#             map_204de276d113ca3fdfba20fe3a326bf8.addControl(mini_map_6b367afe67c01b93c506ce2e54e4be56);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_204de276d113ca3fdfba20fe3a326bf8);
#
#
#             var mouse_position_3f23307097565c8596903fe1022ad404 = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;bottomright&quot;,
#   &quot;separator&quot;: &quot; : &quot;,
#   &quot;emptyString&quot;: &quot;Unavailable&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 5,
#   &quot;prefix&quot;: &quot;&quot;,
# }
#             );
#             mouse_position_3f23307097565c8596903fe1022ad404.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_3f23307097565c8596903fe1022ad404.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_204de276d113ca3fdfba20fe3a326bf8.addControl(mouse_position_3f23307097565c8596903fe1022ad404);
#
#
#             var measure_control_801a38efde85f8a5c6bc17d6364ad816 = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;,
#   &quot;secondaryAreaUnit&quot;: &quot;acres&quot;,
# });
#             map_204de276d113ca3fdfba20fe3a326bf8.addControl(measure_control_801a3

# %% [markdown]
# ## Regroupement de marqueurs (MarkerCluster)
#
# Quand vous avez beaucoup de marqueurs, MarkerCluster les regroupe automatiquement.

# %%
from folium.plugins import MarkerCluster

# Générer des points aléatoires
np.random.seed(42)
n_markers = 50
lats = np.random.normal(45.85, 0.1, n_markers)
lons = np.random.normal(1.25, 0.1, n_markers)

# On créé la carte 
carte = folium.Map(
    location=[45.85, 1.25],
    zoom_start=11
)

# Créer un cluster de marqueurs
marker_cluster = MarkerCluster().add_to(carte)

# Ajouter tous les marqueurs au cluster
for lat, lon in zip(lats, lons):
    folium.Marker(
        location=[lat, lon],
        popup=f'Point ({lat:.4f}, {lon:.4f})'
    ).add_to(marker_cluster)

carte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a4cefadb762db00984a92dd7d71ca97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a4cefadb762db00984a92dd7d71ca97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a4cefadb762db00984a92dd7d71ca97 = L.map(
#                 &quot;map_3a4cefadb762db00984a92dd7d71ca97&quot;,
#                 {
#                     center: [45.85, 1.25],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bbf508cdd16c124d04510ced26cc053 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bbf508cdd16c124d04510ced26cc053.addTo(map_3a4cefadb762db00984a92dd7d71ca97);
#
#
#             var marker_cluster_5fa70c867b0720458216b692f5429d8e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_82daa69ed8121fdba1920a92fc95dbef = L.marker(
#                 [45.89967141530112, 1.2824083969394795],
#                 {
# }
#             ).addTo(marker_cluster_5fa70c867b0720458216b692f5429d8e);
#
#
#         var popup_7d1824feb0201bf54143c58913d7b2ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_518ee8fbf77c2d71a4fa43d530cb400b = $(`&lt;div id=&quot;html_518ee8fbf77c2d71a4fa43d530cb400b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point (45.8997, 1.2824)&lt;/div&gt;`)[0];
#                 popup_7d1824feb0201bf54143c58913d7b2ea.setContent(html_518ee8fbf77c2d71a4fa43d530cb400b);
#
#
#
#         marker_82daa69ed8121fdba1920a92fc95dbef.bindPopup(popup_7d1824feb0201bf54143c58913d7b2ea)
#         ;
#
#
#
#
#             var marker_365a914d3f53f80b08005ba6842dafca = L.marker(
#                 [45.83617356988288, 1.2114917719583684],
#                 {
# }
#             ).addTo(marker_cluster_5fa70c867b0720458216b692f5429d8e);
#
#
#         var popup_760a49b8a1e4a07d2a03c2a60b7f6fca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5e69df460a1fe96d022cb1f2eb3819d = $(`&lt;div id=&quot;html_a5e69df460a1fe96d022cb1f2eb3819d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point (45.8362, 1.2115)&lt;/div&gt;`)[0];
#                 popup_760a49b8a1e4a07d2a03c2a60b7f6fca.setContent(html_a5e69df460a1fe96d022cb1f2eb3819d);
#
#
#
#         marker_365a914d3f53f80b08005ba6842dafca.bindPopup(popup_760a49b8a1e4a07d2a03c2a60b7f6fca)
#         ;
#
#
#
#
#             var marker_edf5ab56817206474421ee684852eed1 = L.marker(
#                 [45.914768853810074, 1.182307799969404],
#                 {
# }
#             ).addTo(marker_cluster_5fa70c867b0720458216b692f5429d8e);
#
#
#         var popup_1377634d87489d8ecbf6eb26faff334b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4278a9c635eb9522aa53a7b6f3d2cb84 = $(`&lt;div id=&quot;html_4278a9c635eb9522aa53a7b6f3d2cb84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point (45.9148, 1.1823)&lt;/div&gt;`)[0];
#                 popup_1377634d87489d8ecbf6eb26faff334b.setContent(html_4278a9c635eb9522aa53a7b6f3d2cb84);
#
#
#
#         marker_edf5ab56817206474421ee684852eed1.bindPopup(popup_1377634d87489d8ecbf6eb26faff334b)
#         ;
#
#
#
#
#             var marker_c993c92e7cfd8ea8bdc9407e1b719918 = L.marker(
#                 [46.0023029856408, 1.3111676288840868],
#                 {
# }
#             ).addTo(marker_cluster_5fa70c867b0720458216b692f5429d8e);
#
#
#         var popup_9a63f5bff06a0820c0e82466ec8bad1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cacf1922acf90446640645d5fbd1469 = $(`&lt;div id=&quot;html_8cacf1922acf90446640645d5fbd1469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point (46.0023, 1.3112)&lt;/div&gt;`)[0];
#                 popup_9a63f5bff06a0820c0e82466ec8bad1c.setContent(html_8cacf1922acf90446640645d5fbd1469);
#
#
#
#         marker_c993c92e7cfd8ea8bdc9407e1b719918.bindPopup(popup_9a63f5bff06a0820c0e82466ec8

# %% [markdown]
# ## Récapitulatif des commandes Folium
#
# ### Créer une carte de base
# ```python
# carte = folium.Map(
#     location=[latitude, longitude],
#     zoom_start=13,
#     tiles='OpenStreetMap'
# )
# ```
#
# ### Ajouter un marqueur
# ```python
# folium.Marker(
#     location=[lat, lon],
#     popup='Texte au clic',
#     tooltip='Texte au survol',
#     icon=folium.Icon(color='red', icon='info-sign')
# ).add_to(carte)
# ```
#
# ### Ajouter un cercle
# ```python
# folium.CircleMarker(
#     location=[lat, lon],
#     radius=10,
#     color='blue',
#     fill=True,
#     fillColor='blue',
#     fillOpacity=0.6
# ).add_to(carte)
# ```
#
# ### Ajouter des polygones depuis GeoPandas
# ```python
# # Convertir en EPSG:4326 d'abord !
# gdf = gdf.to_crs(epsg=4326)
#
# folium.GeoJson(
#     gdf,
#     style_function=lambda x: {'fillColor': 'blue', 'color': 'black'},
#     tooltip=folium.GeoJsonTooltip(fields=['nom'])
# ).add_to(carte)
# ```
#
# ### Créer une carte choroplèthe
# ```python
# folium.Choropleth(
#     geo_data=gdf,
#     data=gdf,
#     columns=['nom_colonne', 'valeur_numérique'],
#     key_on='feature.properties.nom_colonne',
#     fill_color='YlOrRd',
#     legend_name='Légende'
# ).add_to(carte)
# ```
#
# ### Sauvegarder en HTML
# ```python
# carte.save('ma_carte.html')
# ```

# %% [markdown]
# ## Ressources utiles
#
# - **Documentation officielle Folium :** https://python-visualization.github.io/folium/
# - **Liste des icônes Font Awesome :** https://fontawesome.com/v4/icons/
# - **Palettes de couleurs :** https://colorbrewer2.org/
# - **Données géographiques françaises :** https://www.data.gouv.fr/
#
# ## Conseils pour vos projets
#
# 1. **Toujours vérifier le CRS** : Folium nécessite EPSG:4326
# 2. **Tester avec peu de données** : Chargez d'abord un petit échantillon avant de traiter tout le dataset
# 3. **Utiliser MarkerCluster** : Pour plus de 20-30 marqueurs
# 4. **Personnaliser les popups** : Le HTML rend vos cartes plus professionnelles
# 5. **Optimiser les performances** : Évitez d'afficher des milliers de points individuels
